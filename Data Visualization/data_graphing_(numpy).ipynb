# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.tree import plot_tree
from sklearn.metrics import accuracy_score, mean_squared_error

#1. Iris dataset - classification
iris = datasets.load_iris()
X_iris = iris.data
y_iris = iris.target
feature_names_iris = iris.feature_names
class_names_iris = iris.target_names

X_train_iris, X_test_iris, y_train_iris,y_test_iris = train_test_split(X_iris,y_iris, random_state=42)
rf_clf_iris = RandomForestClassifier(n_estimators=5,max_depth=3,random_state=42)
rf_clf_iris.fit(X_train_iris,y_train_iris)
y_pred_iris = rf_clf_iris.predict(X_test_iris)
accuracy_iris = accuracy_score(y_test_iris,y_pred_iris)
print(f"Iris dataset classification accuracy: {accuracy_iris: .2f}")
#               .2 means putting the accuracy down to two decimal places

plt.figure(figsize=(20,10))
plot_tree(rf_clf_iris.estimators_[0],
          feature_names=feature_names_iris,
          class_names=class_names_iris,
          filled=True,
          rounded=True,
          fontsize=10)
plt.title("Iris dataset - First Decision Tree")
plt.show()
# Out:
# Iris dataset classification accuracy:  1.00

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.tree import plot_tree
from sklearn.metrics import accuracy_score, mean_squared_error

#2. Breast Cancer Dataset (named iris to save time

iris = datasets.load_breast_cancer()
X_iris = iris.data
y_iris = iris.target
feature_names_iris = iris.feature_names
class_names_iris = iris.target_names

X_train_iris, X_test_iris, y_train_iris,y_test_iris = train_test_split(X_iris,y_iris, random_state=42)
rf_clf_iris = RandomForestClassifier(n_estimators=5,max_depth=3,random_state=42)
rf_clf_iris.fit(X_train_iris,y_train_iris)
y_pred_iris = rf_clf_iris.predict(X_test_iris)
accuracy_iris = accuracy_score(y_test_iris,y_pred_iris)
print(f"Breast Cancer dataset classification accuracy: {accuracy_iris: .2f}")
#               .2 means putting the accuracy down to two decimal places

plt.figure(figsize=(20,10))
plot_tree(rf_clf_iris.estimators_[0],
          feature_names=feature_names_iris,
          class_names=class_names_iris,
          filled=True,
          rounded=True,
          fontsize=10)
plt.title("Breast Cancer Dataset - Second Decision Tree")
plt.show()
# Out:
# Breast Cancer dataset classification accuracy:  0.96

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.tree import plot_tree
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.tree import DecisionTreeClassifier

df = pd.read_csv("train.csv")
y_data1 = df["Survived"]
s_data = df["Sex"]
a_data = df["Age"]
p_data = df["Pclass"]
X_c = (s_data, a_data, p_data)

#preprocessing
df = df.drop(columns = ["PassengerId","Name","Ticket","Cabin","Fare","SibSp","Parch","Embarked"])

#fill missing values (because some poeple's age or sex or so on arent recorded)
df["Age"] = df["Age"].fillna(df["Age"].median())


#label encoder
le = LabelEncoder()
df["Sex"] = le.fit_transform(df["Sex"])

X = df[["Sex","Age","Pclass"]]
y = df["Survived"]

tree = DecisionTreeClassifier(max_depth=4,random_state=42)
tree.fit(X,y)

plt.figure(figsize=(30,20))
plot_tree(tree,
          feature_names=X.columns,
          class_names = ["Died", "Survived"],
          filled = True,
          rounded=True,
          fontsize=12)

plt.title("Titanic Survival Decision Tree (max_depth=4)")
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.tree import plot_tree
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.tree import DecisionTreeClassifier



df = pd.read_csv("train.csv")

df["Age"] = df["Age"].fillna(df["Age"].median())
df["Fare"] = df["Fare"].fillna(df["Fare"].median)

x_data = data["Age"]
y_data = data["Fare"]
z_data = data["Survived"]
colors = ['red' if s == 0 else 'green' for s in z_data]

plt.figure(figsize=(10,6))
plt.scatter(x_data,y_data,color=c)
plt.xlabel("Age")
plt.ylabel("Fare")
plt.title("Titanic Survival Age vs Fare (Survived = Green, Deceased = Red)")
plt.grid()
plt.show()

# %%
pip install pandas_profiling==3.6.6
# Out:
# ERROR: Ignored the following versions that require a different python version: 3.3.0 Requires-Python >=3.7, <3.11; 3.4.0 Requires-Python >=3.7, <3.11; 3.5.0 Requires-Python >=3.7, <3.11; 3.6.0 Requires-Python >=3.7, <3.11; 3.6.1 Requires-Python >=3.7, <3.11; 3.6.2 Requires-Python >=3.7, <3.11; 3.6.3 Requires-Python >=3.7, <3.11; 3.6.4 Requires-Python >=3.7, <3.11; 3.6.5 Requires-Python >=3.7, <3.11; 3.6.6 Requires-Python >=3.7, <3.11
# ERROR: Could not find a version that satisfies the requirement pandas_profiling==3.6.6 (from versions: 3.0.0, 3.1.0, 3.2.0)
# ERROR: No matching distribution found for pandas_profiling==3.6.6

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt
from scipy.stats import kurtosis,skew
import seaborn as sns
from pandas_profilling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-41e923b5f566> in <cell line: 0>()
#       6 from scipy.stats import kurtosis,skew
#       7 import seaborn as sns
# ----> 8 from pandas_profilling import ProfileReport
#
# ModuleNotFoundError: No module named 'pandas_profilling'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
df = pd.read_csv("Mall_Customers.csv")

# %%
df.drop("CustomerID", axis=1, inplace=True)

# %%
df["Gender"] = df["Gender"].map({"Male": 0, "Female": 1})

# %%
df.columns=["Gender","Age","Annual_Income","Spending_Score(1-100)"]

# %%
df.isnull().sum()
# Out:
# Gender                   0
# Age                      0
# Annual_Income            0
# Spending_Score(1-100)    0
# dtype: int64

# %%
df.describe()
# Out:
#            Gender         Age  Annual_Income  Spending_Score(1-100)
# count  200.000000  200.000000     200.000000             200.000000
# mean     0.560000   38.850000      60.560000              50.200000
# std      0.497633   13.969007      26.264721              25.823522
# min      0.000000   18.000000      15.000000               1.000000
# 25%      0.000000   28.750000      41.500000              34.750000
# 50%      1.000000   36.000000      61.500000              50.000000
# 75%      1.000000   49.000000      78.000000              73.000000
# max      1.000000   70.000000     137.000000              99.000000

# %%
df.corr()
# Out:
#                          Gender       Age  Annual_Income  Spending_Score(1-100)
# Gender                 1.000000 -0.060867      -0.056410               0.058109
# Age                   -0.060867  1.000000      -0.012398              -0.327227
# Annual_Income         -0.056410 -0.012398       1.000000               0.009903
# Spending_Score(1-100)  0.058109 -0.327227       0.009903               1.000000

# %%
df["Annual_Income"].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
sns.scatterplot(x="Annual_Income",y="Spending_Score(1-100)",hue="Gender",data=df,s=150,palette="tab10")
# Out:
# <Axes: xlabel='Annual_Income', ylabel='Spending_Score(1-100)'>

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt
from scipy.stats import kurtosis,skew
import seaborn as sns

# %%
df = pd.read_csv("titanic.csv")

# %%
df["Gender"] = df["Gender"].fillna(df["Gender"].median())

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 8 columns]

# %%
df = pd.read_csv("titanic.csv")
df["Gender"] = df["Gender"].fillna(df["Gender"].median())
sns.relplot(x="Age", y="Survived",data=df,kind="scatter", height=8,aspect=1.3)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df = sns.load_dataset("titanic")
print(df.isnull().sum())
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df["age"].fillna(df["age"].median(),inplace=True)
df["embarked"].fillna(df["embarked"].mode()[0],inplace=True)
df["embark_town"].fillna(df["embark_town"].mode()[0],inplace=True)
df.drop(columns=["deck"],inplace=True)

df["survival_status"] = df["survived"].map({0:"Did not survive",1:"Survived"})

print(df.head(3))
# Out:
#    survived  pclass     sex   age  ...  embark_town  alive  alone  survival_status
# 0         0       3    male  22.0  ...  Southampton     no  False  Did not survive
# 1         1       1  female  38.0  ...    Cherbourg    yes  False         Survived
# 2         1       3  female  26.0  ...  Southampton    yes   True         Survived
#
# [3 rows x 15 columns]
# <ipython-input-100-52b23720e8f2>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["age"].fillna(df["age"].median(),inplace=True)
# ...

# %%
print("Survival Count: ")
print(df["survived"].value_counts())

print("\nSurvival Rate by Sex: ")
print(df.groupby("sex")["survived"].mean())

print("\nSurvival Rate by Class:")
print(df.groupby("pclass")["survived"].mean)
# Out:
# Survival Count:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64
#
# Survival Rate by Sex:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64
#
# Survival Rate by Class:
# <bound method GroupBy.mean of <pandas.core.groupby.generic.SeriesGroupBy object at 0x7de3a3e8d090>>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('dark_background')
sns.set_context("talk")

plt.figure(figsize=(8, 6))
sns.scatterplot(x='age', y='fare', data=df, hue='survival_status', palette={'Did not survive': 'crimson', 'Survived': 'lime'}, alpha=0.7)

plt.title('Age vs Fare (colored by survival)')
plt.xlabel("Age")
plt.ylabel("Fare")
plt.legend(title="Survival Status")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('dark_background')
sns.set_context("talk")

plt.figure(figsize=(8, 6))
sns.boxplot(x='class', y='fare', data=df, hue='survival_status', palette={'Class 1': 'crimson', 'Survived': 'lime'})

plt.title('Class vs Fare (colored by survival)')
plt.xlabel("Class")
plt.ylabel("Fare")
plt.legend(title="Survival Status")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-127-83654295cb57> in <cell line: 0>()
#       6
#       7 plt.figure(figsize=(8, 6))
# ----> 8 sns.boxplot(x='class', y='fare', data=df, hue='survival_status', palette={'Class 1': 'crimson', 'Survived': 'lime'})
#       9
#      10 plt.title('Class vs Fare (colored by survival)')
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1595 ):
#    1596
# -> 1597     p = _CategoricalPlotter(
#    1598         data=data,
#    1599         variables=dict(x=x, y=y, hue=hue),
#
# ...

# %%
plt.figure(figsize=(8,6))
sns.boxplot
# Out:
# <function seaborn.categorical.boxplot(data=None, *, x=None, y=None, hue=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, fill=True, dodge='auto', width=0.8, gap=0, whis=1.5, linecolor='auto', linewidth=None, fliersize=None, hue_norm=None, native_scale=False, log_scale=None, formatter=None, legend='auto', ax=None, **kwargs)>

# %%
df = sns.load_dataset('titanic')

numeric_cols = ['survived','pclass','age','sibsp','parch','fare']
corr = df[numeric_cols].corr()

plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True,fmt=".2f",cmap='coolwarm',center=0)
plt.title("Correlation Heatmap of Numerical Features")
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.show()

# %%
fig,axes = plt.subplots(1,2,figsize=(14,6))

sns.scatterplot(x="age",y='fare',data=df,ax=axes[0],color='cyan',alpha = 0.7)
axes[0].set_title('age vs fare')
axes[0].set_xlabel('age')
axes[0].set_ylabel('fare')

sns.boxplot(x='survival_status',y='age',data=df,ax=axes[1],palette='Pastel2')
axes[1].set_title("age distribution by survival status")
axes[1].set_xlabel('survival status')
axes[1].set_ylabel('age')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-116-50cbe10ed381>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='survival_status',y='age',data=df,ax=axes[1],palette='Pastel2')

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='age',y='fare',data=df,size='pclass',sizes={1:200,2:100,3:50},hue="sex",style='survival_status',palette={"male":"dodgerblue","female":"orange"},alpha=0.7)
plt.title('age vs fare (size-class,color-sex,shape-survival)')
plt.xlabel('age')
plt.ylabel('fare')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
df = sns.load_dataset('tips')
print(df)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df = sns.load_dataset('tips')

numeric_cols = ['total_bill','tip','sex','smoker','size']
df["smoker"] = df["smoker"].map({"No": 0, "Yes": 1})
df["sex"] = df["sex"].map({"Male": 0, "Female": 1})


corr = df[numeric_cols].corr()

plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True,fmt=".2f",cmap='coolwarm',center=0)
plt.title("Correlation Heatmap of Numerical Features")
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("diabetes.csv")

numeric_cols = ['Pregnancies','Glucose','BloodPressure','SkinThickness','BMI',"Age","Outcome"]

corr = df[numeric_cols].corr()

plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True,fmt=".2f",cmap='coolwarm',center=0)
plt.title("Correlation Heatmap of Diabetes")
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.show()

#number 1

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt
from scipy.stats import kurtosis,skew
import seaborn as sns

df = pd.read_csv("Medicaldataset.csv")

plt.figure(figsize=(10,10))
df["Result"] = df["Result"].replace({"negative": 0, "positive": 1})
sns.scatterplot(x='Age',y='Blood sugar',data=df,hue="Result",palette={0:"dodgerblue",1:"orange"},alpha=0.7)
plt.title('age vs blood sugar (blue = tested positive for heart disease, orange = the latter)')
plt.xlabel('Age')
plt.ylabel('Blood sugar')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

#number 2
# Out:
# <ipython-input-21-f6c93028f8fd>:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Result"] = df["Result"].replace({"negative": 0, "positive": 1})

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("Finance_data.csv")
df["Investment_Avenues"] = df["Investment_Avenues"].map({"No": 0, "Yes": 1})

numeric_cols = ["age", "Investment_Avenues", "Mutual_Funds", "Equity_Market", "Debentures", "Government_Bonds", "Fixed_Deposits"]

corr = df[numeric_cols].corr()
age_corr = corr["age"].drop("age")

plt.figure(figsize=(8, 6))
sns.heatmap(age_corr.to_frame(), annot=True, fmt=".2f", cmap='coolwarm', center=0, cbar_kws={'label': 'Correlation Coefficient'})
plt.title("Correlation of age with investment experience")
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.show()

#number 3

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('creditcard.csv')

d = df["V1"]
norm = df["V1"].median()
outlier = (d > norm + 20) | (d < norm - 20)
plt.figure(figsize=(10, 25))

plt.scatter(df.index, d, c=outlier.map({True: 'red', False: 'blue'}), alpha=0.5)
plt.ylabel("V1")
plt.xlabel("Index")
plt.title("Outlier Detection in V1")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('habit.csv')

df.drop(columns=["student_id","gender","part_time_job","diet_quality","parental_education_level","internet_quality","extracurricular_participation"],inplace=True)
numeric_cols = ["age","study_hours_per_day","social_media_hours","netflix_hours","attendance_percentage","sleep_hours","exercise_frequency","mental_health_rating","exam_score"]

corr = df[numeric_cols].corr()
age_corr = corr["age"].drop("age")

plt.figure(figsize=(8,6))
sns.heatmap(age_corr.to_frame(), annot=True, fmt=".2f", cmap='coolwarm', center=0, cbar_kws={'label': 'Correlation Coefficient'})
plt.title("Correlation Heatp Map")
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('dropout.csv')

plt.figure(figsize=(5,3))
df["target"] = df["target"].replace({"Dropout": 0, "Graduate": 1, "Enrolled": 2}).infer_objects(copy=False)
sns.scatterplot(x='target', y='GDP', data=df, hue="Marital Status", alpha=0.7)
plt.title('School Success - Success')
plt.xlabel('2: Enrolled, 1: Graduate, 0: Dropout')
plt.ylabel('Debt/Afloat')
plt.legend(bbox_to_anchor=(1, 1), loc='upper left')
plt.show()
# Out:
# <ipython-input-15-05019fa9d7e0>:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["target"] = df["target"].replace({"Dropout": 0, "Graduate": 1, "Enrolled": 2}).infer_objects(copy=False)
